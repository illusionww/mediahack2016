# %%
import requests
from bs4 import BeautifulSoup

# %%
def getByUrl(url):
    soup = BeautifulSoup(requests.get(url).text, 'html.parser')
    listContainer = soup.find(id='listContainer')
    titles = listContainer.findAll('header')
    results = []
    for title in titles:
        results.append((title.a.text, title.a['href']))
    return results

# %%
all_links = []
for page in range(1, 10):
    url = 'https://xpir.ru/finsources?page=' + str(page) + '&finSourceType=08d75e615e7d46fd80bc6e0d9fc9606f&auditory=b4db5577b2f94d38be9f6eca89f71dc4'
    all_links.extend(getByUrl(url))

# %%
def getConcrete(name, link):
    url = 'https://xpir.ru' + link
    soup = BeautifulSoup(requests.get(url).text, 'html.parser')
    
    link = soup.find('div', {"class": "fin-link"}).a['href']
    volumes = soup.findAll('span', {"class": "fin-investment-size-text"})
    volume_low, volume_high = volumes[0].text if len(volumes) > 0 else None, volumes[1].text if len(volumes) > 1 else None
    raw_data = soup.find('div', {'class': 'fin-not-idividual'}).findAll('div', {'class': 'info-block-in'})
    data = [data.text for data in raw_data]
    return {'name': name, 'link': link, 'volume_low': volume_low, 'volume_high': volume_high, 
            'data': data}

# %%
dataset = []
for name, link in all_links:
    data = getConcrete(name, link)
    dataset.append(data)

# %%
import pandas as pd
df = pd.DataFrame(dataset)
df = df[["name", "link", "volume_lo"]]
# Out:
#                                                  data  \
# 0   [\n\n, \n\n            Виды поддержки\n       ...
# 1   [\n\n, \n\n            Виды поддержки\n       ...
# 2   [\n\n, \n\n            Виды поддержки\n       ...
# 3   [\n\n, \n\n            Виды поддержки\n       ...
# 4   [\n\n, \n\n            Виды поддержки\n       ...
# 5   [\n\n, \n\n            Виды поддержки\n       ...
# 6   [\n\n, \n\n            Виды поддержки\n       ...
# 7   [\n\n, \n\n            Виды поддержки\n       ...
# 8   [\n\n, \n\n            Виды поддержки\n       ...
# 9   [\n\n, \n\n            Виды поддержки\n       ...
# 10  [\n\n, \n\n            Виды поддержки\n       ...
# 11  [\n\n, \n\n            Виды поддержки\n       ...
# 12  [\n\n, \n\n            Виды поддержки\n       ...
# 13  [\n\n, \n\n            Виды поддержки\n       ...
# 14  [\n\n, \n\n            Виды поддержки\n       ...
# 15  [\n\n, \n\n            Виды поддержки\n       ...
# 16  [\n\n, \n\n            Виды поддержки\n       ...
# 17  [\n\n, \n\n            Виды поддержки\n       ...
# 18  [\n\n, \n\n            Виды поддержки\n       ...
# 19  [\n\n, \n\n            Виды поддержки\n       ...
# 20  [\n\n, \n\n            Виды поддержки\n       ...
# 21  [\n\n, \n\n            Виды поддержки\n       ...
# 22  [\n\n, \n\n            Виды поддержки\n       ...
# 23  [\n\n, \n\n            Виды поддержки\n       ...
# 24  [\n\n, \n\n            Виды поддержки\n       ...
# 25  [\n\n, \n\n            Виды поддержки\n       ...
# 26  [\n\n, \n\n            Виды поддержки\n       ...
# 27  [\n\n, \n\n            Виды поддержки\n       ...
# 28  [\n\n, \n\n            Виды поддержки\n       ...
# 29  [\n\n, \n\n            Виды поддержки\n       ...
# ..                                                ...
# 55  [\n\n, \n\n            Виды поддержки\n       ...
# 56  [\n\n, \n\n            Виды поддержки\n       ...
# 57  [\n\n, \n\n            Виды поддержки\n       ...
# 58  [\n\n, \n\n            Виды поддержки\n       ...
# 59  [\n\n, \n\n            Виды поддержки\n       ...
# 60  [\n\n, \n\n            Виды поддержки\n       ...
# 61  [\n\n, \n\n            Виды поддержки\n       ...
# 62  [\n\n, \n\n            Виды поддержки\n       ...
# 63  [\n\n, \n\n            Виды поддержки\n       ...
# 64  [\n\n, \n\n            Виды поддержки\n       ...
# 65  [\n\n, \n\n            Виды поддержки\n       ...
# 66  [\n\n, \n\n            Виды поддержки\n       ...
# 67  [\n\n, \n\n            Виды поддержки\n       ...
# 68  [\n\n, \n\n            Виды поддержки\n       ...
# 69  [\n\n, \n\n            Виды поддержки\n       ...
# 70  [\n\n, \n\n            Виды поддержки\n       ...
# 71  [\n\n, \n\n            Виды поддержки\n       ...
# 72  [\n\n, \n\n            Виды поддержки\n       ...
# 73  [\n\n, \n\n            Виды поддержки\n       ...
# 74  [\n\n, \n\n            Виды поддержки\n       ...
# 75  [\n\n, \n\n            Виды поддержки\n       ...
# 76  [\n\n, \n\n            Виды поддержки\n       ...
# 77  [\n\n, \n\n            Виды поддержки\n       ...
# 78  [\n\n, \n\n            Виды поддержки\n       ...
# 79  [\n\n, \n\n            Виды поддержки\n       ...
# 80  [\n\n, \n\n            Виды поддержки\n       ...
# 81  [\n\n, \n\n            Виды поддержки\n       ...
# 82  [\n\n, \n\n            Виды поддержки\n       ...
# 83  [\n\n, \n\n            Виды поддержки\n       ...
# 84  [\n\n, \n\n            Виды поддержки\n       ...
#
#                                                  link  \
# 0                            http://sk.ru/foundation/
# 1                                http://gaidarfund.ru
# 2                            http://www.rusventure.ru
# 3                                   http://www.rfh.ru
# 4                                 http://www.rfbr.ru/
# 5                               http://www.fpi.gov.ru
# 6                                http://www.fasie.ru/
# 7                                 http://www.rftr.ru/
# 8                              http://www.rusnano.com
# 9                                  http://www.dfg.de/
# 10                    http://www.mars.dti.ne.jp/~mif/
# 11                                 http://ikf2010.ru/
# 12                            http://alferov-fond.ru/
# 13                                    http://rscf.ru/
# 14               https://www.bifonds.de/homepage.html
# 15                               http://vernadsky.ru/
# 16                             http://www.sf-kras.ru/
# 17                           http://gorchakovfund.ru/
# 18                             http://innopraktika.ru
# 19                               http://www.tusur.ru/
# 20                            http://so-edinenie.org/
# 21                           http://ivf.tatarstan.ru/
# 22                          http://www.bf.sistema.ru/
# 23                                 http://www.fpff.ru
# 24                              http://volnoe-delo.ru
# 25                                     http://omz.ru/
# 26                                 http://fondnid.ru/
# 27                                    http://scisc.ru
# 28                                  http://qwcap.com/
# 29                              http://biotechfund.ru
# ..                                                ...
# 55                               http://www.airvo.ru/
# 56                           http://zam.catalysis.ru/
# 57                        http://www.hcfoundation.ru/
# 58                            http://endowment.tpu.ru
# 59                    http://www.euler-foundation.org
# 60                           http://www.volsu.ru/fck/
# 61                            http://oxfordrussia.ru/
# 62                         http://www.fondpotanin.ru/
# 63                        http://www.prokhorovfund.ru
# 64                     http://www.endowment.sfedu.ru/
# 65                             http://www.nb-fund.com
# 66                          http://www.eifgrants.org/
# 67                            http://ecsocman.hse.ru/
# 68  http://www.sibai.ru/novosibirskij-oblastnoj-fo...
# 69                         http://www.e-birzha.cap.ru
# 70  https://www.rotary.org/myrotary/en/rotary-foun...
# 71                             http://www.jsps.go.jp/
# 72                             http://www.rosalux.de/
# 73      http://www.cnv-stiftung.de/en/startseite.html
# 74                       http://www.fmsh.fr/fr/c/1295
# 75                           http://www.rfntr.neva.ru
# 76                                   http://leorsa.ru
# 77              http://www.rockefellerfoundation.org/
# 78                          http://www.energy-fund.ru
# 79                  http://www.volkswagenstiftung.de/
# 80  http://www.bp.com/ru_ru/lubricants/russia/abou...
# 81                          http://www.neweurasia.ru/
# 82                                http://www.stint.se
# 83                http://www.angelicoventures.com/ru/
# 84                          http://www.samarafond.ru/
#
#                                                  name   volume_high  \
# 0                                    Фонд «Сколково»           None
# 1                                 Фонд Егора Гайдара       Р100 000
# 2                 ОАО "Российская венчурная компания"          None
# 3               Российский гуманитарный научный фонд           None
# 4   РФФИ (Российский фонд фундаментальных исследов...          None
# 5                     Фонд перспективных исследований          None
# 6   Фонд содействия развитию малых форм предприяти...   Р15 000 000
# 7          Российский фонд технологического развития           None
# 8    Фонд инфраструктурных и образовательных программ          None
# 9                    German Research Foundation (DFG)          None
# 10              The Matsumae International Foundation          None
# 11              Международный фонд Н. Д. Кондратьева           None
# 12  Фонд поддержки образования и науки (Алфёровски...          None
# 13                            Российский научный фонд  Р270 000 000
# 14                          Фонд Берингер-Ингельхайм           None
# 15                       Фонд имени В.И. Вернадского           None
# 16  Красноярский краевой фонд поддержки научной и ...          None
# 17                                     Фонд Горчакова          None
# 18                           Компания «Иннопрактика»           None
# 19  Томский государственный университет систем упр...          None
# 20           Фонд поддержки слепоглухих "Со-единение"          None
# 21  Инвестиционно-венчурный фонд республики Татарстан  Р650 000 000
# 22                  Благотворительный фонд «Система»           None
# 23       Фонд поддержки фундаментальной физики (ФПФФ)          None
# 24               Фонд Олега Дерипаска «Вольное Дело»           None
# 25       Объединенные машиностроительные заводы (ОМЗ)          None
# 26  Новосибирский областной фонд поддержки науки и...          None
# 27  Межрегиональный общественный фонд «Сибирский ц...          None
# 28                          Quantum Wave Fund (Qwave)   $10 000 000
# 29            Фонд поддержки передовых биотехнологий           None
# ..                                                ...           ...
# 55  НП «Агентство инвестиционного развития Волгогр...   Р30 000 000
# 56  Международный благотворительный научный фонд и...       Р67 000
# 57                           Фонд «Научный потенциал»          None
# 58  Фонд целевого капитала Томского политехническо...      Р100 000
# 59                                       Фонд Эйлера           None
# 60  Фонд целевого капитала Волгоградского государс...          None
# 61                                Oxford Russia Fund        Р10 000
# 62                                      Фонд Потанина      Р500 000
# 63                             Фонд Михаила Прохорова          None
# 64                         Фонд целевого капитала ЮФУ    Р1 000 000
# 65  Фонд региональных социальных программ "Наше бу...    Р3 000 000
# 66                 Engineering Information Foundation       $25 000
# 67  The Alexander von Humboldt Foundation (Фонд им...    €5 000 000
# 68  Новосибирский областной фонд поддержки науки и...      Р100 000
# 69  Фонд содействия развитию венчурных инвестиций ...   Р70 000 000
# 70                                  Rotary Foundation          None
# 71  Japan Society for the Promotion of Science (JSPS)          None
# 72                           Фонд им. Розы Люксембург          None
# 73                  Фонд Кристианы Нюсселяйн-Вольхард          None
# 74  Фонд «Дом наук о человеке» (Foundation Maison ...          None
# 75  Региональный фонд научно-технического развития...          None
# 76                         Leorsa Group of Companies           None
# 77                         The Rockefeller Foundation          None
# 78                         Фонд «Энергия без границ»           None
# 79             Фонд Фольксваген (Volkswagen Stiftung)          None
# 80                                        Компания BP      $100 000
# 81  Фонд содействия социальному развитию «Новая Ев...          None
# 82  STINT, the Swedish Foundation for Internationa...          None
# 83                                  Angelico Ventures    $5 000 000
# 84               Инновационный фонд Самарской области          None
#
#       volume_low
# 0   Р300 000 000
# 1        Р10 000
# 2     Р3 000 000
# 3       Р500 000
# 4   Р400 000 000
# 5           None
# 6       Р200 000
# 7   Р150 000 000
# 8     Р1 000 000
# 9        €10 000
# 10          None
# 11          None
# 12      Р250 000
# 13    Р5 000 000
# 14          €300
# 15       Р24 000
# 16          None
# 17          None
# 18          None
# 19          None
# 20          None
# 21    Р1 000 000
# 22      Р150 000
# 23       Р30 000
# 24      Р300 000
# 25          None
# 26      Р300 000
# 27    Р1 000 000
# 28    $2 000 000
# 29    Р1 000 000
# ..           ...
# 55       Р10 000
# 56       Р35 000
# 57      Р500 000
# 58       Р10 000
# 59      Р100 000
# 60      Р170 000
# 61        Р6 000
# 62       Р15 000
# 63      Р100 000
# 64       Р10 000
# 65       Р50 000
# 66        $5 000
# 67       €25 000
# 68       Р10 000
# 69   Р20 000 000
# 70       $10 000
# 71          None
# 72        €7 000
# 73        €4 800
# 74       €12 000
# 75      Р500 000
# 76    $1 000 000
# 77      $100 000
# 78          None
# 79          None
# 80       $10 000
# 81    Р1 000 000
# 82       $50 000
# 83      $250 000
# 84   Р80 000 000
#
# [85 rows x 5 columns]
